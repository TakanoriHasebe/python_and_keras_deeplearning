# %% [markdown]
# Sequentialモデルは、ネットワークの入力と出力がそれぞれ１つだけあることを前提として、<br>
# 層の線形スタックで構成されている。<br>

# %%
# 画像の表示
from IPython.display import Image
Image(filename='00.png', width=500)

# %% [markdown]
# タスクによってはマルチモーダル入力が必要になる。<br>
# 例として、古着の市場価値を予想するディープラーニングモデルを思い浮かべる。<br>

# %% [markdown]
# モデルの入力として、「ユーザのメタデータ・テキストの説明・商品の写真」があるとする。<br>
# 上記の３つを「個々」にではなく「同時」に使用するにはどのようにしたら良いだろうか？<br>

# %%
# 画像の表示
from IPython.display import Image
Image(filename='01.png', width=500)

# %% [markdown]
# 同様に小説のテキストが存在するとする。<br>
# 小説をジャンル別に分類かつ、小説の執筆時期も知りたいとする。<br>
# どのようにしたらようだろうか？<br>

# %%
# 画像の表示
from IPython.display import Image
Image(filename='02.png', width=500)

# %% [markdown]
# また、最近開発されているニューラルアーキテクチャは、非線形のネットワークトポロジを要求する。<br>
# Googleによって開発されたInceptionファミリネットワークは、Inceptionモジュールに依存している。<br>
# これらのモジュールの入力は、複数の並列畳み込み分岐によって処理される。<br>
# そして、それらの分岐の出力は１つのテンソルにマージされる。<br>

# %%
# 画像の表示
from IPython.display import Image
Image(filename='03.png', width=400)

# %% [markdown]
# また、最近の傾向として、モデルに残差接続を追加することも行われている。<br>
# 例として、ResNetがあげられる。<br>

# %%
# 画像の表示
from IPython.display import Image
Image(filename='04.png', width=400)

# %% [markdown]
# 多入力モデル、多出力モデル、グラフ形式のモデルはKerasでSequentialモデルクラスを使用するだけでは不可能。<br>
# 上記の３つを可能にするために、Functional APIが存在する。<br>
